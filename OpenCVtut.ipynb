# %%
import cv2

# %%
import numpy as np

# %%
img = cv2.imread('Capture.png',0)

# %%
rows,cols = img.shape

# %%
M = np.float32([[1,0,0],[0,1,0]])

# %%
dst = cv2.warpAffine(img,M,(cols,rows))

# %%
cv2.imshow('img',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
M = cv2.getRotationMatrix2D((cols/2, rows/2),0,1)
dst = cv2.warpAffine(img, M, (cols, rows))

# %%
cv2.imshow('img',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread('Capture.png')

# %%
rows,cols,ch = img.shape

# %%
pts1 = np.float32([[56,65],[368,52],[28,387],[389,390]])
pts2 = np.float32([[0,0],[300,0],[0,300],[300,300]])

# %%
M = cv2.getPerspectiveTransform(pts1,pts2)

# %%
dst = cv2.warpPerspective(img,M,(300,300))

# %%
import matplotlib.pyplot as plt

# %%
plt.subplot(121),plt.imshow(img),plt.title('Input')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x13d2fa10358>,
#  <matplotlib.image.AxesImage at 0x13d2fa530f0>,
#  <matplotlib.text.Text at 0x13d2fa2e3c8>)

# %%
plt.subplot(122),plt.imshow(dst),plt.title('Output')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x13d2fa53780>,
#  <matplotlib.image.AxesImage at 0x13d2fa98470>,
#  <matplotlib.text.Text at 0x13d2fa80860>)

# %%
plt.show()

# %%
kernel = np.ones((5,5),np.float32)/25

# %%
dst = cv2.filter2D(img,-1,kernel)

# %%
plt.subplot(121),plt.imshow(img),plt.title('Original')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x13d2ff10780>,
#  <matplotlib.image.AxesImage at 0x13d2ff8f8d0>,
#  <matplotlib.text.Text at 0x13d2ff70b38>)

# %%
plt.xticks([]), plt.yticks([])
# Out:
# (([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x13d2ff984a8>,
#  <matplotlib.image.AxesImage at 0x13d2ffe5630>,
#  <matplotlib.text.Text at 0x13d2ffc3898>)

# %%
plt.xticks([]), plt.yticks([])
# Out:
# (([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
plt.show()

# %%
blur = cv2.bilateralFilter(img,9,75,75)

# %%
plt.subplot(121),plt.imshow(img),plt.title('Original')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x13d2f9c7550>,
#  <matplotlib.image.AxesImage at 0x13d30a42be0>,
#  <matplotlib.text.Text at 0x13d30a238d0>)

# %%
plt.xticks([]), plt.yticks([])
# Out:
# (([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
plt.subplot(122),plt.imshow(blur),plt.title('Blur')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x13d30a497b8>,
#  <matplotlib.image.AxesImage at 0x13d30a952b0>,
#  <matplotlib.text.Text at 0x13d30a71940>)

# %%
plt.xticks([]), plt.yticks([])
plt.show()
