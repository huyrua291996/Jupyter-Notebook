# %%
# !py -3 -m pip install dota2api
# Out:
# ...
#   Running setup.py bdist_wheel for dota2api: started
#   Running setup.py bdist_wheel for dota2api: finished with status 'done'
#   Stored in directory: C:\Users\huyru\AppData\Local\pip\Cache\wheels\91\da\02\daa9d680eaa445c5dce3c1ca7951af66a2674821adda512535
# Successfully built dota2api
# ...

# %%
import dota2api

# %%
api = dota2api.Initialise('074DD9348D256EA3822CB3D554AF37AE')

# %%
api.get_heroes()
# Out:
# {'count': 115,
#  'heroes': [{'id': 1,
#    'localized_name': 'Anti-Mage',
#    'name': 'npc_dota_hero_antimage',
#    'url_full_portrait': 'http://cdn.dota2.com/apps/dota2/images/heroes/antimage_full.png',
#    'url_large_portrait': 'http://cdn.dota2.com/apps/dota2/images/heroes/antimage_lg.png',
#    'url_small_portrait': 'http://cdn.dota2.com/apps/dota2/images/heroes/antimage_sb.png',
#    'url_vertical_portrait': 'http://cdn.dota2.com/apps/dota2/images/heroes/antimage_vert.jpg'},
#   {'id': 2,
#    'localized_name': 'Axe',
#    'name': 'npc_dota_hero_axe',
#    'url_full_portrait': 'http://cdn.dota2.com/apps/dota2/images/heroes/axe_full.png',
#    'url_large_portrait': 'http://cdn.dota2.com/apps/dota2/images/heroes/axe_lg.png',
#    'url_small_portrait': 'http://cdn.dota2.com/apps/dota2/images/heroes/axe_sb.png',
#    'url_vertical_portrait': 'http://cdn.dota2.com/apps/dota2/images/heroes/axe_vert.jpg'},
#   {'id': 3,
#    'localized_name': 'Bane',
# ...

# %%
api.get_game_items()
# Out:
# {'items': [{'cost': 2250,
#    'id': 1,
#    'localized_name': 'Blink Dagger',
#    'name': 'item_blink',
#    'recipe': 0,
#    'secret_shop': 0,
#    'side_shop': 1,
#    'url_image': 'http://cdn.dota2.com/apps/dota2/images/items/blink_lg.png'},
#   {'cost': 420,
#    'id': 2,
#    'localized_name': 'Blades of Attack',
#    'name': 'item_blades_of_attack',
#    'recipe': 0,
#    'secret_shop': 0,
#    'side_shop': 0,
#    'url_image': 'http://cdn.dota2.com/apps/dota2/images/items/blades_of_attack_lg.png'},
#   {'cost': 1200,
#    'id': 3,
#    'localized_name': 'Broadsword',
#    'name': 'item_broadsword',
#    'recipe': 0,
#    'secret_shop': 0,
#    'side_shop': 1,
#    'url_image': 'http://cdn.dota2.com/apps/dota2/images/items/broadsword_lg.png'},
#   {'cost': 550,
#    'id': 4,
#    'localized_name': 'Chainmail',
#    'name': 'item_chainmail',
#    'recipe': 0,
#    'secret_shop': 0,
#    'side_shop': 1,
# ...

# %%
api.get_team_info_by_team_id('Evil Geniuses')
# Out:
# {'status': 1,
#  'teams': [{'admin_account_id': 86011339,
#    'calibration_games_remaining': 3,
#    'country_code': 'sg',
#    'games_played': 439,
#    'logo': 711904559424929169,
#    'logo_sponsor': 711904559424929675,
#    'name': 'Zenith',
#    'player_0_account_id': 84772440,
#    'player_1_account_id': 85417034,
#    'player_2_account_id': 86011339,
#    'tag': 'Zenith',
#    'time_created': 1338330222,
#    'url': 'www.dota2.com.cn'},
#   {'admin_account_id': 28291366,
#    'calibration_games_remaining': 3,
#    'country_code': 'us',
#    'games_played': 2,
#    'league_id_0': 65001,
#    'league_id_1': 9584,
#    'league_id_10': 3902,
#    'league_id_11': 9,
#    'league_id_12': 3092,
#    'league_id_13': 8055,
#    'league_id_14': 1761,
#    'league_id_15': 3341,
#    'league_id_16': 4580,
#    'league_id_17': 5336,
#    'league_id_18': 5196,
#    'league_id_19': 5522,
#    'league_id_2': 9601,
#    'league_id_20': 4357,
#    'league_id_21': 3779,
# ...

# %%
api.update_heroes()
